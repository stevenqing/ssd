# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# load data from dir_
relative_dir = "coin3_reward_PPO/REWARDPPOTrainer_coin3_env_0_2024-01-19_04-14-040do7n3er/progress.csv"
dir_ = "~/ray_results/{}".format(relative_dir)
data = pd.read_csv(dir_)
# print(data.head())

rew_f = "info/learner/agent-{}/reward_loss"
reg_f = "info/learner/agent-{}/reg_loss"
reward_loss = data[rew_f.format(0)]
reg_loss = data[reg_f.format(0)]


# plot
fig, ax = plt.subplots()
ax.plot(reward_loss, label="reward loss")
# ax.plot(reg_loss, label="reg loss")
ax.set_xlabel("iteration")
ax.set_ylabel("loss")
# import seaborn as sns
# sns.set()
# Out:
# Text(0, 0.5, 'loss')
